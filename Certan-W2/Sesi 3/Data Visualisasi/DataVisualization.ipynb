# %% [markdown]
# # Data Preprocessing & Visualization
#
# ### Nama: Oktova Y. P. Samosir
# ### NIM : 42324001

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, roc_curve, auc, roc_auc_score
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
# Load dataset
df = sns.load_dataset("iris")
# 1. Histogram → Distribusi
plt.figure(figsize=(6,4))
sns.histplot(df['petal_length'], bins=20, kde=True)
plt.title("Histogram: Distribution of Petal Length")
plt.show()

# %%
# 2. Bar Chart → Count per category
plt.figure(figsize=(6,4))
sns.countplot(x="species", data=df)
plt.title("Bar Chart: Count of Species")
plt.show()

# %%
# 3. Box Plot → Spread + Outlier detection
plt.figure(figsize=(6,4))
sns.boxplot(x="species", y="petal_length", data=df)
plt.title("Box Plot: Petal Length by Species")
plt.show()

# %%
# 4. Scatter Plot → Relationship
plt.figure(figsize=(6,4))
sns.scatterplot(x="sepal_length", y="petal_length", hue="species", data=df)
plt.title("Scatter Plot: Sepal Length vs Petal Length")
plt.show()

# %%
# 5. Pair Plot → Multivariate relationship
sns.pairplot(df, hue="species")
plt.suptitle("Pair Plot: Feature Relationships", y=1.02)
plt.show()

# %%
# 6. Line Plot → Example time series (simulate cumulative sum)
plt.figure(figsize=(6,4))
df["random_growth"] = np.random.randn(len(df)).cumsum()
sns.lineplot(x=df.index, y="random_growth", data=df)
plt.title("Line Plot: Simulated Growth Over Index")
plt.show()

# %%
# 7. Heatmap → Correlation matrix
plt.figure(figsize=(6,4))
sns.heatmap(df.select_dtypes(include="number").corr(), annot=True, cmap="coolwarm")
plt.title("Heatmap: Feature Correlation")
plt.show()

# %%
# 8. 3D Scatter Plot → 3 features visualization
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot(111, projection="3d")
species = df["species"].unique()
colors = ["r", "g", "b"]
for sp, col in zip(species, colors):
 subset = df[df["species"] == sp]
 ax.scatter(subset["sepal_length"], subset["sepal_width"], subset["petal_length"],
 c=col, label=sp, s=50)
ax.set_xlabel("Sepal Length")
ax.set_ylabel("Sepal Width")
ax.set_zlabel("Petal Length")
ax.set_title("3D Scatter Plot: Sepal Length, Sepal Width, Petal Length")
ax.legend()
plt.show()

# %%
# 9. Model-Specific Visualization (e.g Modeling using RandomForest)
# Split data
X = df.drop("species", axis=1)
y = df["species"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Train model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
# 9.1. Confusion Matrix
cm = confusion_matrix(y_test, y_pred, labels=model.classes_)
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=model.classes_, yticklabels=model .classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# 9.2. ROC-AUC Curve (multi-class with One-vs-Rest)
# Binarize labels
y_bin = label_binarize(y, classes=model.classes_)
n_classes = y_bin.shape[1]

# Train OvR classifier
ovr_model = OneVsRestClassifier(RandomForestClassifier(n_estimators=100, random_state=42))
ovr_model.fit(X_train, label_binarize(y_train, classes=model.classes_))

y_score = ovr_model.predict_proba(X_test)
y_test_bin = label_binarize(y_test, classes=model.classes_)

# Plot ROC curve
plt.figure(figsize=(7, 5))
for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"Class {model.classes_[i]} (AUC = {roc_auc:.2f})")

plt.plot([0, 1], [0, 1], "k--") 
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC-AUC Curve (One-vs-Rest)")
plt.legend()
plt.show()

# %%
# 9.3. Feature Importance Plot → Random Forest
X = df.drop("species", axis=1)
y = df["species"]
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X, y)
importances = model.feature_importances_
features = X.columns
plt.figure(figsize=(6,4))
sns.barplot(x=importances, y=features)
plt.title("Feature Importance Plot (Random Forest)")
plt.show()

# %%
# %pip install --upgrade seaborn matplotlib
# Out:
# Requirement already satisfied: seaborn in C:\Users\Oktovaaaaa\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in C:\Users\Oktovaaaaa\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.11.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in C:\Users\Oktovaaaaa\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from seaborn) (2.5.3)
# Requirement already satisfied: pandas>=1.2 in C:\Users\Oktovaaaaa\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from seaborn) (3.0.5)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Oktovaaaaa\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Oktovaaaaa\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in C:\Users\Oktovaaaaa\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Oktovaaaaa\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Oktovaaaaa\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in C:\Users\Oktovaaaaa\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Oktovaaaaa\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Oktovaaaaa\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Oktovaaaaa\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas>=1.2->seaborn) (2026.4)
# Requirement already satisfied: six>=1.5 in C:\Users\Oktovaaaaa\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas matplotlib seaborn scikit-learn numpy
# Out:
# Collecting pandas
#   Using cached pandas-3.0.5-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.11.2-cp314-cp314-win_amd64.whl.metadata (80 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.9.1-cp314-cp314-win_amd64.whl.metadata (9.3 kB)
# Collecting numpy
#   Using cached numpy-2.5.3-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Oktovaaaaa\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Downloading tzdata-2026.4-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.4.0-cp314-cp314-win_amd64.whl.metadata (3.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib)
#   Downloading fonttools-4.65.0-cp314-cp314-win_amd64.whl.metadata (127 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.5.1-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Oktovaaaaa\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.3)
# Collecting pillow>=9 (from matplotlib)
#   Using cached pillow-12.3.0-cp314-cp314-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Using cached scipy-1.18.1-cp314-cp314-win_amd64.whl.metadata (61 kB)
# Collecting joblib>=1.4.0 (from scikit-learn)
#   Using cached joblib-1.6.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting narwhals>=2.0.1 (from scikit-learn)
#   Using cached narwhals-2.26.0-py3-none-any.whl.metadata (15 kB)
# Collecting threadpoolctl>=3.5.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting cloudpickle>=3.0 (from joblib>=1.4.0->scikit-learn)
#   Using cached cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: six>=1.5 in C:\Users\Oktovaaaaa\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-3.0.5-cp314-cp314-win_amd64.whl (10.0 MB)
# Downloading matplotlib-3.11.2-cp314-cp314-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.5 MB 1.2 MB/s eta 0:00:08
#    --- ------------------------------------ 0.8/9.5 MB 1.2 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.0/9.5 MB 1.2 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.3/9.5 MB 1.2 MB/s eta 0:00:07
#    ------ --------------------------------- 1.6/9.5 MB 1.2 MB/s eta 0:00:07
#    ------- -------------------------------- 1.8/9.5 MB 1.2 MB/s eta 0:00:07
#    ------- -------------------------------- 1.8/9.5 MB 1.2 MB/s eta 0:00:07
#    --------- ------------------------------ 2.4/9.5 MB 1.2 MB/s eta 0:00:06
#    --------- ------------------------------ 2.4/9.5 MB 1.2 MB/s eta 0:00:06
#    --------- ------------------------------ 2.4/9.5 MB 1.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 2.6/9.5 MB 1.1 MB/s eta 0:00:07
#    ------------- -------------------------- 3.1/9.5 MB 1.1 MB/s eta 0:00:06
#    ------------- -------------------------- 3.1/9.5 MB 1.1 MB/s eta 0:00:06
#    -------------- ------------------------- 3.4/9.5 MB 1.1 MB/s eta 0:00:06
#    --------------- ------------------------ 3.7/9.5 MB 1.1 MB/s eta 0:00:06
#    ---------------- ----------------------- 3.9/9.5 MB 1.1 MB/s eta 0:00:06
#    ----------------- ---------------------- 4.2/9.5 MB 1.1 MB/s eta 0:00:05
#    ------------------ --------------------- 4.5/9.5 MB 1.1 MB/s eta 0:00:05
#    ------------------- -------------------- 4.7/9.5 MB 1.1 MB/s eta 0:00:05
#    -------------------- ------------------- 5.0/9.5 MB 1.1 MB/s eta 0:00:04
#    ---------------------- ----------------- 5.2/9.5 MB 1.1 MB/s eta 0:00:04
#    ----------------------- ---------------- 5.5/9.5 MB 1.1 MB/s eta 0:00:04
#    ----------------------- ---------------- 5.5/9.5 MB 1.1 MB/s eta 0:00:04
#    ------------------------ --------------- 5.8/9.5 MB 1.1 MB/s eta 0:00:04
#    ------------------------- -------------- 6.0/9.5 MB 1.1 MB/s eta 0:00:04
#    -------------------------- ------------- 6.3/9.5 MB 1.1 MB/s eta 0:00:03
#    --------------------------- ------------ 6.6/9.5 MB 1.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 6.8/9.5 MB 1.1 MB/s eta 0:00:03
#    ----------------------------- ---------- 7.1/9.5 MB 1.1 MB/s eta 0:00:03
#    ------------------------------ --------- 7.3/9.5 MB 1.1 MB/s eta 0:00:02
#    ------------------------------- -------- 7.6/9.5 MB 1.1 MB/s eta 0:00:02
#    --------------------------------- ------ 7.9/9.5 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 8.1/9.5 MB 1.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 8.4/9.5 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------ --- 8.7/9.5 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 8.9/9.5 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.5 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 1.2 MB/s  0:00:08
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached scikit_learn-1.9.1-cp314-cp314-win_amd64.whl (8.4 MB)
# Using cached numpy-2.5.3-cp314-cp314-win_amd64.whl (12.7 MB)
# Downloading contourpy-1.4.0-cp314-cp314-win_amd64.whl (240 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.65.0-cp314-cp314-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.5 MB 1.5 MB/s eta 0:00:02
#    ------------ --------------------------- 0.8/2.5 MB 1.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.0/2.5 MB 1.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.0/2.5 MB 1.4 MB/s eta 0:00:02
#    ------------------------- -------------- 1.6/2.5 MB 1.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.8/2.5 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.5 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 1.6 MB/s  0:00:01
# Using cached joblib-1.6.0-py3-none-any.whl (306 kB)
# Using cached cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Using cached kiwisolver-1.5.1-cp314-cp314-win_amd64.whl (72 kB)
# Using cached narwhals-2.26.0-py3-none-any.whl (474 kB)
# Using cached pillow-12.3.0-cp314-cp314-win_amd64.whl (7.2 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Using cached scipy-1.18.1-cp314-cp314-win_amd64.whl (37.4 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading tzdata-2026.4-py2.py3-none-any.whl (347 kB)
# Installing collected packages: tzdata, threadpoolctl, pyparsing, pillow, numpy, narwhals, kiwisolver, fonttools, cycler, cloudpickle, scipy, pandas, joblib, contourpy, scikit-learn, matplotlib, seaborn
#
#    ----------------------------------------  0/17 [tzdata]
#    ----------------------------------------  0/17 [tzdata]
#    ----------------------------------------  0/17 [tzdata]
#    ---- -----------------------------------  2/17 [pyparsing]
#    ---- -----------------------------------  2/17 [pyparsing]
#    ------- --------------------------------  3/17 [pillow]
#    ------- --------------------------------  3/17 [pillow]
#    ------- --------------------------------  3/17 [pillow]
#    ------- --------------------------------  3/17 [pillow]
#    ------- --------------------------------  3/17 [pillow]
#    ------- --------------------------------  3/17 [pillow]
#    ------- --------------------------------  3/17 [pillow]
#    ------- --------------------------------  3/17 [pillow]
#    ------- --------------------------------  3/17 [pillow]
#    ------- --------------------------------  3/17 [pillow]
#    ------- --------------------------------  3/17 [pillow]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    --------- ------------------------------  4/17 [numpy]
#    ----------- ----------------------------  5/17 [narwhals]
#    ----------- ----------------------------  5/17 [narwhals]
#    ----------- ----------------------------  5/17 [narwhals]
#    ----------- ----------------------------  5/17 [narwhals]
#    ----------- ----------------------------  5/17 [narwhals]
#    ----------- ----------------------------  5/17 [narwhals]
#    ----------- ----------------------------  5/17 [narwhals]
#    ----------- ----------------------------  5/17 [narwhals]
#    ----------- ----------------------------  5/17 [narwhals]
#    ----------- ----------------------------  5/17 [narwhals]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    --------------------- ------------------  9/17 [cloudpickle]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ----------------------- ---------------- 10/17 [scipy]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ---------------------------- ----------- 12/17 [joblib]
#    ---------------------------- ----------- 12/17 [joblib]
#    ---------------------------- ----------- 12/17 [joblib]
#    ---------------------------- ----------- 12/17 [joblib]
#    ---------------------------- ----------- 12/17 [joblib]
#    ------------------------------ --------- 13/17 [contourpy]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    -------------------------------- ------- 14/17 [scikit-learn]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ----------------------------------- ---- 15/17 [matplotlib]
#    ------------------------------------- -- 16/17 [seaborn]
#    ------------------------------------- -- 16/17 [seaborn]
#    ------------------------------------- -- 16/17 [seaborn]
#    ------------------------------------- -- 16/17 [seaborn]
#    ---------------------------------------- 17/17 [seaborn]
#
# Successfully installed cloudpickle-3.1.2 contourpy-1.4.0 cycler-0.12.1 fonttools-4.65.0 joblib-1.6.0 kiwisolver-1.5.1 matplotlib-3.11.2 narwhals-2.26.0 numpy-2.5.3 pandas-3.0.5 pillow-12.3.0 pyparsing-3.3.2 scikit-learn-1.9.1 scipy-1.18.1 seaborn-0.13.2 threadpoolctl-3.6.0 tzdata-2026.4
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\Oktovaaaaa\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\Oktovaaaaa\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
